# %% [markdown]
# #Create the environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/ESoWC
# Out:
# /content/drive/My Drive/ESoWC

# %%
import pandas as pd
import xarray as xr
import numpy as np

#Our class
from create_dataset.make_dataset import CustomDataset

# %% [markdown]
# #Create the CO dataset

# %% [markdown]
# I want to apply the following changes to the datasets:
# *   cut_region function: the dataset contains a larger region than the one we are analyzing, so we proceed to eliminate the excess area
# *   rescale function: we change the scale of the dataset from 0.75 degree to 0.25 degree
# *   resample function: we create a time series with an hourly frequency

# %% [markdown]
# Extremes of the region that we are analyzing:

# %%
lat_s = 43.0
lat_n = 51.0
lon_e =  4.0
lon_w = 12.0

# %% [markdown]
# ##05_2019
#
# This dataset already exist and it is called 05_2019_weather_and_CO.nc

# %%
dataset_togheter_05_19 = xr.open_dataset('Data/05_2019_weather_and_CO.nc')
dataset_togheter_05_19
# Out:
# <xarray.Dataset>
# Dimensions:         (latitude: 33, longitude: 33, time: 742)
# Coordinates:
#   * time            (time) datetime64[ns] 2019-05-01 ... 2019-05-31T21:00:00
#   * latitude        (latitude) float64 43.0 43.25 43.5 43.75 ... 50.5 50.75 51.0
#   * longitude       (longitude) float64 4.0 4.25 4.5 4.75 ... 11.5 11.75 12.0
# Data variables: (12/15)
#     EMISSIONS_2019  (time, latitude, longitude) float64 ...
#     u10             (time, latitude, longitude) float64 ...
#     v10             (time, latitude, longitude) float64 ...
#     hcc             (time, latitude, longitude) float64 ...
#     lcc             (time, latitude, longitude) float64 ...
#     tcc             (time, latitude, longitude) float64 ...
#     ...              ...
#     tmp             (time, latitude, longitude) float64 ...
#     sp_hum          (time, latitude, longitude) float64 ...
#     rel_hum         (time, latitude, longitude) float64 ...
# ...

# %% [markdown]
# ##07_2019

# %% [markdown]
# Now we apply the changes to the july 2019 dataset of CO emissions

# %%
CO_instance_07_19 = CustomDataset('Data/JUL_HOURLY_2019_CO_reduced.nc')
CO_instance_07_19.cut_region(lat_n, lat_s, lon_e, lon_w)
CO_instance_07_19.rescale()
CO_instance_07_19.resample("1H")
CO_Dataset_07_19 = CO_instance_07_19.get_dataset()
CO_Dataset_07_19 = CO_Dataset_07_19.drop_vars('crs')
# Out:
# Opening dataset at :  Data/JUL_HOURLY_2019_CO_reduced.nc
# Done!

# %% [markdown]
# Here we upload the weather dataset

# %%
weather_dataset_07_19 = xr.open_dataset('Data/07_2019_weather.nc')

# %% [markdown]
# Now we merge the weather with the CO emissions

# %%
dataset_togheter_07_19 = CO_Dataset_07_19.merge(weather_dataset_07_19)
dataset_togheter_07_19
# Out:
# <xarray.Dataset>
# Dimensions:         (latitude: 33, longitude: 33, time: 745)
# Coordinates:
#   * time            (time) datetime64[ns] 2019-07-01 ... 2019-08-01
#   * latitude        (latitude) float64 43.0 43.25 43.5 43.75 ... 50.5 50.75 51.0
#   * longitude       (longitude) float64 4.0 4.25 4.5 4.75 ... 11.5 11.75 12.0
# Data variables: (12/15)
#     EMISSIONS_2019  (time, latitude, longitude) float64 nan nan ... -3.361e-13
#     u10             (time, latitude, longitude) float64 -0.8357 -0.5034 ... nan
#     v10             (time, latitude, longitude) float64 1.102 1.413 ... nan nan
#     hcc             (time, latitude, longitude) float64 0.02545 0.01697 ... nan
#     lcc             (time, latitude, longitude) float64 0.4397 0.3733 ... nan
#     tcc             (time, latitude, longitude) float64 0.4584 0.3857 ... nan
#     ...              ...
#     tmp             (time, latitude, longitude) float64 295.9 296.0 ... nan nan
# ...

# %% [markdown]
# Here we save the merged dataset

# %%
dataset_togheter_07_19.to_netcdf('Data/07_2019_weather_and_CO.nc', 'w', 'NETCDF4')

# %% [markdown]
# ##05_2020

# %% [markdown]
# Now we apply the changes to the may 2020 dataset of CO emissions

# %%
CO_instance_05_20 = CustomDataset('Data/MAY_HOURLY_2020_CO_reduced.nc')
CO_instance_05_20.cut_region(lat_n, lat_s, lon_e, lon_w)0
CO_instance_05_20.rescale()
CO_instance_05_20.resample("1H")
CO_Dataset_05_20 = CO_instance_05_20.get_dataset()
CO_Dataset_05_20 = CO_Dataset_05_20.drop_vars('crs')
# Out:
# Opening dataset at :  Data/MAY_HOURLY_2020_CO_reduced.nc
# Done!

# %% [markdown]
# Here we upload the weather dataset

# %%
weather_dataset_05_20 = xr.open_dataset('Data/05_2020_weather.nc')

# %% [markdown]
# Now we merge the weather with the CO emissions

# %%
dataset_togheter_05_20 = CO_Dataset_05_20.merge(weather_dataset_05_20)
dataset_togheter_05_20
# Out:
# <xarray.Dataset>
# Dimensions:         (latitude: 33, longitude: 33, time: 742)
# Coordinates:
#   * time            (time) datetime64[ns] 2020-05-01 ... 2020-05-31T21:00:00
#   * latitude        (latitude) float64 43.0 43.25 43.5 43.75 ... 50.5 50.75 51.0
#   * longitude       (longitude) float64 4.0 4.25 4.5 4.75 ... 11.5 11.75 12.0
# Data variables: (12/15)
#     EMISSIONS_2020  (time, latitude, longitude) float64 nan nan nan ... nan nan
#     u10             (time, latitude, longitude) float64 ...
#     v10             (time, latitude, longitude) float64 ...
#     hcc             (time, latitude, longitude) float64 ...
#     lcc             (time, latitude, longitude) float64 ...
#     tcc             (time, latitude, longitude) float64 ...
#     ...              ...
#     tmp             (time, latitude, longitude) float64 ...
#     sp_hum          (time, latitude, longitude) float64 ...
#     rel_hum         (time, latitude, longitude) float64 ...
# ...

# %% [markdown]
# Here we save the merged dataset

# %%
dataset_togheter_05_20.to_netcdf('Data/05_2020_weather_and_CO.nc', 'w', 'NETCDF4')
