# %% [markdown]
# #Create the environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/ESoWC
# Out:
# /content/drive/My Drive/ESoWC

# %%
import pandas as pd
import xarray as xr
import numpy as np

# %% [markdown]
# #Create the dataset

# %%
dataset = xr.open_dataset('Data/05_2019_weather_and_CO.nc')
dataset = dataset.sortby(['latitude','longitude','time'])  
dataframe = dataset.to_dataframe()
dataframe = dataframe.reset_index()
dataframe = dataframe.set_index('time')
dataframe.head()
# Out:
#                      latitude  longitude  ...        tcw  tot_wind
# time                                      ...
# 2019-05-01 00:00:00      43.0        4.0  ...  15.114744  6.296568
# 2019-05-01 01:00:00      43.0        4.0  ...  14.682165  5.841263
# 2019-05-01 02:00:00      43.0        4.0  ...  14.249586  5.454147
# 2019-05-01 03:00:00      43.0        4.0  ...  13.817007  5.150618
# 2019-05-01 04:00:00      43.0        4.0  ...  13.647179  4.817765
#
# [5 rows x 17 columns]

# %%
dataframe['tmp_shift_1']=dataframe.groupby(['latitude','longitude']).tmp.shift(periods=1)
dataframe.head(10)
# Out:
#                      latitude  longitude  ...  tot_wind  tmp_shift_1
# time                                      ...
# 2019-05-01 00:00:00      43.0        4.0  ...  6.296568          NaN
# 2019-05-01 01:00:00      43.0        4.0  ...  5.841263   290.124512
# 2019-05-01 02:00:00      43.0        4.0  ...  5.454147   289.665548
# 2019-05-01 03:00:00      43.0        4.0  ...  5.150618   289.206584
# 2019-05-01 04:00:00      43.0        4.0  ...  4.817765   288.747620
# 2019-05-01 05:00:00      43.0        4.0  ...  4.485566   288.495534
# 2019-05-01 06:00:00      43.0        4.0  ...  4.154178   288.243449
# 2019-05-01 07:00:00      43.0        4.0  ...  3.579648   287.991364
# 2019-05-01 08:00:00      43.0        4.0  ...  3.005943   288.240936
# 2019-05-01 09:00:00      43.0        4.0  ...  2.433645   288.490509
#
# [10 rows x 18 columns]

# %%
dataframe['tot_wind_shift_12']=dataframe.groupby(['latitude','longitude']).tot_wind.shift(periods=12)
dataframe.head(15)
# Out:
#                      latitude  longitude  ...  tmp_shift_1  tot_wind_shift_12
# time                                      ...
# 2019-05-01 00:00:00      43.0        4.0  ...          NaN                NaN
# 2019-05-01 01:00:00      43.0        4.0  ...   290.124512                NaN
# 2019-05-01 02:00:00      43.0        4.0  ...   289.665548                NaN
# 2019-05-01 03:00:00      43.0        4.0  ...   289.206584                NaN
# 2019-05-01 04:00:00      43.0        4.0  ...   288.747620                NaN
# 2019-05-01 05:00:00      43.0        4.0  ...   288.495534                NaN
# 2019-05-01 06:00:00      43.0        4.0  ...   288.243449                NaN
# 2019-05-01 07:00:00      43.0        4.0  ...   287.991364                NaN
# 2019-05-01 08:00:00      43.0        4.0  ...   288.240936                NaN
# 2019-05-01 09:00:00      43.0        4.0  ...   288.490509                NaN
# 2019-05-01 10:00:00      43.0        4.0  ...   288.740082                NaN
# 2019-05-01 11:00:00      43.0        4.0  ...   288.608032                NaN
# 2019-05-01 12:00:00      43.0        4.0  ...   288.475983           6.296568
# 2019-05-01 13:00:00      43.0        4.0  ...   288.343933           5.841263
# 2019-05-01 14:00:00      43.0        4.0  ...   288.287415           5.454147
#
# [15 rows x 19 columns]

# %%
dataframe['rel_hum_shift_8']=dataframe.groupby(['latitude','longitude']).rel_hum.shift(periods=8)
dataframe.head(10)
# Out:
#                      latitude  longitude  ...  tot_wind_shift_12  rel_hum_shift_8
# time                                      ...
# 2019-05-01 00:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 01:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 02:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 03:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 04:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 05:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 06:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 07:00:00      43.0        4.0  ...                NaN              NaN
# 2019-05-01 08:00:00      43.0        4.0  ...                NaN         0.000219
# 2019-05-01 09:00:00      43.0        4.0  ...                NaN         0.000227
#
# [10 rows x 20 columns]

# %%
dataframe = dataframe.reset_index()
dataframe = dataframe.set_index(['latitude','longitude','time'])
dataframe.head()
# Out:
#                                         EMISSIONS_2019  ...  rel_hum_shift_8
# latitude longitude time                                 ...
# 43.0     4.0       2019-05-01 00:00:00             NaN  ...              NaN
#                    2019-05-01 01:00:00    1.605808e-13  ...              NaN
#                    2019-05-01 02:00:00    1.405082e-13  ...              NaN
#                    2019-05-01 03:00:00    1.354900e-13  ...              NaN
#                    2019-05-01 04:00:00    1.354900e-13  ...              NaN
#
# [5 rows x 18 columns]

# %%
ds_final=dataframe.to_xarray()
ds_final
# Out:
# <xarray.Dataset>
# Dimensions:            (latitude: 33, longitude: 33, time: 742)
# Coordinates:
#   * latitude           (latitude) float64 43.0 43.25 43.5 ... 50.5 50.75 51.0
#   * longitude          (longitude) float64 4.0 4.25 4.5 4.75 ... 11.5 11.75 12.0
#   * time               (time) datetime64[ns] 2019-05-01 ... 2019-05-31T21:00:00
# Data variables: (12/18)
#     EMISSIONS_2019     (latitude, longitude, time) float64 nan 1.606e-13 ... nan
#     u10                (latitude, longitude, time) float64 2.632 2.961 ... 1.161
#     v10                (latitude, longitude, time) float64 -5.72 ... 0.8654
#     hcc                (latitude, longitude, time) float64 0.0 0.0 ... 0.9778
#     lcc                (latitude, longitude, time) float64 0.04311 ... 0.1257
#     tcc                (latitude, longitude, time) float64 0.04311 ... 0.9966
#     ...                 ...
#     tcwv               (latitude, longitude, time) float64 15.11 14.68 ... 25.31
#     tcw                (latitude, longitude, time) float64 15.11 14.68 ... 25.4
#     tot_wind           (latitude, longitude, time) float64 6.297 5.841 ... 1.448
#     tmp_shift_1        (latitude, longitude, time) float64 nan 290.1 ... 291.2
#     tot_wind_shift_12  (latitude, longitude, time) float64 nan nan ... 2.726
#     rel_hum_shift_8    (latitude, longitude, time) float64 nan nan ... 0.00014

# %% [markdown]
# #Check

# %%
dataframe.isnull().sum()
# Out:
# EMISSIONS_2019       23958
# u10                      0
# v10                      0
# hcc                      0
# lcc                      0
# tcc                      0
# cvl                      0
# cvh                      0
# sp                       0
# tmp                      0
# sp_hum                   0
# rel_hum                  0
# tcwv                     0
# tcw                      0
# tot_wind                 0
# tmp_shift_1           1089
# tot_wind_shift_12    13068
# rel_hum_shift_8       8712
# dtype: int64

# %%
ds_final.isel(time=[15]).EMISSIONS_2019.plot()

# %%
ds_final.isel(time=[15]).u10.plot()

# %%
ds_final.isel(time=[15]).tmp.plot()

# %% [markdown]
# #Save the dataset

# %%
ds_final.to_netcdf('Data/05_2019_weather_and_CO_for_model.nc', 'w', 'NETCDF4')
