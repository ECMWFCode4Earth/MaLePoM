# %% [markdown]
# # Machine learning model for emissions estimations from concentrations

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, Embedding, LSTM
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.backend import square, mean

# %% [markdown]
# In this notebook we will apply a Recurrrent Neural Network model to a dataset of concentrations in order to estimate emissions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/ESoWC
# Out:
# /content/drive/My Drive/ESoWC

# %% [markdown]
# ## Datasets

# %%
from create_dataset.make_dataset import CustomDataset

fn = 'Data/3_months_dataset_complete_for_model_CO_notraffic_3std.nc'
ds = CustomDataset(fn)
# Out:
# Opening dataset at :  Data/3_months_dataset_complete_for_model_CO_notraffic_3std.nc
# Done!

# %% [markdown]
# Assuming data are already cleaned from NaN and error values

# %%
df = ds.get_dataset().to_dataframe().dropna() # drop nan because 
df = df.reset_index().drop(columns=['latitude', 'longitude']).set_index('time')
df
# Out:
#                         EMISSIONS       u10  ...  O3_tc_add_trend   traffic
# time                                         ...
# 2019-05-01 12:00:00  6.484499e-13  0.285356  ...         0.007345  0.000000
# 2019-05-01 13:00:00  6.373653e-13  0.203581  ...         0.007455  0.000000
# 2019-05-01 14:00:00  6.484499e-13  0.121806  ...         0.007430  0.000000
# 2019-05-01 15:00:00  6.318230e-13  0.040032  ...         0.007406  0.000000
# 2019-05-01 16:00:00  6.429076e-13  0.154884  ...         0.007385  0.000000
# ...                           ...       ...  ...              ...       ...
# 2020-05-29 20:00:00 -6.246814e-12 -2.627069  ...         0.007583  0.035814
# 2020-05-29 21:00:00 -5.882417e-12 -2.385035  ...         0.007578  0.000000
# 2020-05-29 22:00:00 -4.580997e-12 -2.518724  ...         0.007572  0.000000
# 2020-05-29 23:00:00 -2.238442e-12 -2.652414  ...         0.007566  0.000000
# 2020-05-30 00:00:00 -1.665817e-12 -2.786104  ...         0.007560  0.000000
#
# [1181625 rows x 32 columns]

# %%
df.describe()
# Out:
#           EMISSIONS           u10  ...  O3_tc_add_trend       traffic
# count  1.181625e+06  1.181625e+06  ...     1.181625e+06  1.181625e+06
# mean   2.961075e-11  1.566229e-01  ...     7.950631e-03  2.380547e+01
# std    8.705480e-11  1.737978e+00  ...     4.911953e-04  5.104009e+01
# min   -4.220594e-10 -1.003736e+01  ...     6.783178e-03 -5.317852e-06
# 25%   -7.437105e-13 -8.000104e-01  ...     7.620413e-03  0.000000e+00
# 50%    1.900547e-13  1.334152e-01  ...     7.857858e-03  0.000000e+00
# 75%    1.815774e-11  1.043527e+00  ...     8.187944e-03  2.328992e+01
# max    5.119497e-10  1.136522e+01  ...     1.013695e-02  6.059825e+02
#
# [8 rows x 32 columns]

# %% [markdown]
# # Model for all locations

# %% [markdown]
# Now let's try a model which takes into account all data points available. The way to do that is the following:
# - The data generator sample a tuple (latitude, longitude)
# - Then fixed the location the generator sample a subsequence from the given location

# %% [markdown]
# Separate target variable from independent variables

# %%
df_target = df['EMISSIONS']
df.drop(columns=['EMISSIONS'], inplace=True)

# %% [markdown]
# Now we have a training set with 12 features and 771007 samples

# %% [markdown]
# ### NumPy Arrays
#
# We now convert the Pandas data-frames to NumPy arrays that can be input to the neural network.

# %%
x_data = df.values

# %%
y_data = df_target.values

# %% [markdown]
# This is the number of observations (aka. data-points or samples) in the data-set:

# %%
num_data = len(x_data)
num_data
# Out:
# 1181625

# %% [markdown]
# This is the fraction of the data-set that will be used for the training-set:

# %%
train_split = 0.8

# %% [markdown]
# This is the number of observations in the training-set:

# %%
num_train = int(train_split * num_data)
num_train
# Out:
# 945300

# %% [markdown]
# This is the number of observations in the validation-set:

# %%
num_val = int(train_split * num_train)
num_val
# Out:
# 756240

# %% [markdown]
# This is the number of observations in the test-set:

# %%
num_test = num_data - num_train
num_test
# Out:
# 236325

# %% [markdown]
# These are the input-signals for the training- and test-sets:

# %%
x_train = x_data[0:num_train]
x_val = x_train[-num_val:]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 1181625

# %% [markdown]
# These are the output-signals for the training- and test-sets:

# %%
y_train = y_data[0:num_train].reshape(-1,1)# Reshape like this if you have a single feature
y_val = y_train[-num_val:].reshape(-1, 1)
y_test = y_data[num_train:].reshape(-1,1)
len(y_train) + len(y_test)
# Out:
# 1181625

# %% [markdown]
# This is the number of input-signals:

# %%
num_x_signals = x_data.shape[1]
num_x_signals
# Out:
# 31

# %% [markdown]
# This is the number of output-signals:

# %%
y_data = y_data.reshape(-1, 1)
num_y_signals = y_data.shape[1]
num_y_signals
# Out:
# 1

# %% [markdown]
# ### Scaled Data
#
# The data-set contains a wide range of values:

# %%
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: -15.172348022460938
# Max: 102864.15625

# %% [markdown]
# The neural network works best on values roughly between -1 and 1, so we need to scale the data before it is being input to the neural network. We can use `scikit-learn` for this.
#
# We first create a scaler-object for the input-signals.

# %%
x_scaler = MinMaxScaler()

# %% [markdown]
# We then detect the range of values from the training-data and scale the training-data.

# %%
x_train_scaled = x_scaler.fit_transform(x_train)

# %% [markdown]
# Apart from a small rounding-error, the data has been scaled to be between 0 and 1.

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: 0.0
# Max: 1.0000000000000004

# %% [markdown]
# We use the same scaler-object for the input-signals in the test-set.

# %%
x_val_scaled = x_scaler.transform(x_val)
x_test_scaled = x_scaler.transform(x_test)

# %% [markdown]
# The target-data comes from the same data-set as the input-signals, because it is the weather-data for one of the cities that is merely time-shifted. But the target-data could be from a different source with different value-ranges, so we create a separate scaler-object for the target-data.

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_val_scaled = y_scaler.transform(y_val)
y_test_scaled = y_scaler.transform(y_test)

# %% [markdown]
# ## Data Generator
#
# The data-set has now been prepared as 2-dimensional numpy arrays.

# %%
print(x_train_scaled.shape)
print(y_train_scaled.shape)
# Out:
# (945300, 31)
# (945300, 1)

# %% [markdown]
# Instead of training the Recurrent Neural Network on the complete sequences of almost 300k observations, we will use the following function to create a batch of shorter sub-sequences picked at random from the training-data.

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %% [markdown]
# We will use a large batch-size so as to keep the GPU near 100% work-load. You may have to adjust this number depending on your GPU, its RAM and your choice of `sequence_length` below.

# %%
batch_size = 50 #hyperparameter

# %%
sequence_length = 24 # 1 day of sequence, hyperparameter
sequence_length
# Out:
# 24

# %% [markdown]
# We then create the batch-generator.

# %%
generator = batch_generator(batch_size=batch_size,
                            sequence_length=sequence_length)

# %% [markdown]
# We can then test the batch-generator to see if it works.

# %%
x_batch, y_batch = next(generator)

# %% [markdown]
# This gives us a random batch of 24 sequences, each sequence having 24 observations, and each observation having 12 input-signals and 1 output-signals.

# %%
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (50, 24, 31)
# (50, 24, 1)

# %% [markdown]
# We can plot one of the 20 input-signals as an example.

# %%
batch = 0   # First sequence in the batch.
signal = 0  # First signal from the 12 input-signals.
seq = x_batch[batch, :, signal]
plt.plot(seq)

# %% [markdown]
# We can also plot one of the output-signals that we want the model to learn how to predict given all those 20 input signals.

# %%
seq = y_batch[batch, :, signal]
plt.plot(seq)

# %% [markdown]
# ### Validation Set
#
# The neural network trains quickly so we can easily run many training epochs. But then there is a risk of overfitting the model to the training-set so it does not generalize well to unseen data. We will therefore monitor the model's performance on the test-set after each epoch and only save the model's weights if the performance is improved on the test-set.
#
# The batch-generator randomly selects a batch of short sequences from the training-data and uses that during training. But for the validation-data we will instead run through the entire sequence from the test-set and measure the prediction accuracy on that entire sequence, this is done due to the lack of data.

# %%
validation_data = (np.expand_dims(x_val_scaled, axis=0),
                   np.expand_dims(y_val_scaled, axis=0))

# %% [markdown]
# ## Create the Recurrent Neural Network
#
# We are now ready to create the Recurrent Neural Network (LSTM). We will use the Keras API for this because of its simplicity.

# %%
model = Sequential()

# %% [markdown]
# We can now add a Gated Recurrent Unit (GRU) to the network. This will have 64 outputs for each time-step in the sequence.
#
# Note that because this is the first layer in the model, Keras needs to know the shape of its input, which is a batch of sequences of arbitrary length (indicated by `None`), where each observation has a number of input-signals (`num_x_signals`).

# %%
'''model.add(LSTM(units=64,
              return_sequences=True,
              input_shape=(None, num_x_signals,)))'''
# Out:
# 'model.add(LSTM(units=64,\n              return_sequences=True,\n              input_shape=(None, num_x_signals,)))'

# %% [markdown]
# The GRU outputs a batch of sequences of 64 values. We want to predict 1 output-signals, so we add a fully-connected (or dense) layer which maps 64 values down to only 1 values.
#
# The output-signal in the data-set have been limited to be between 0 and 1 using a scaler-object. So we also limit the output of the neural network using the Sigmoid activation function, which squashes the output to be between 0 and 1.

# %%
'''model.add(Dense(128, activation='relu',input_shape=(None, num_x_signals,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(Dense(num_y_signals, activation='linear'))'''
# Out:
# "model.add(Dense(128, activation='relu',input_shape=(None, num_x_signals,)))\nmodel.add(Dense(64, activation='relu'))\nmodel.add(Dense(32, activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.001)))\nmodel.add(Dense(num_y_signals, activation='linear'))"

# %%
model.add(Dense(128, activation='relu',input_shape=(None, num_x_signals,)))
model.add(Dense(64, activation='relu'))
#model.add(Dense(32, activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.0001)))
model.add(Dense(32, activation='relu'))

model.add(Dense(num_y_signals, activation='linear'))

# %% [markdown]
# A problem with using the Sigmoid activation function, is that we can now only output values in the same range as the training-data.
#
# For example, if the training-data only has temperatures between -20 and +30 degrees, then the scaler-object will map -20 to 0 and +30 to 1. So if we limit the output of the neural network to be between 0 and 1 using the Sigmoid function, this can only be mapped back to temperature values between -20 and +30.
#
# We can use a linear activation function on the output instead. This allows for the output to take on arbitrary values. It might work with the standard initialization for a simple network architecture, but for more complicated network architectures e.g. with more layers, it might be necessary to initialize the weights with smaller values to avoid `NaN` values during training. You may need to experiment with this to get it working.
# Since the netowrk is quite simple and shallow.

# %%
if False:
    from tensorflow.python.keras.initializers import RandomUniform

    # Maybe use lower init-ranges.
    init = RandomUniform(minval=-0.05, maxval=0.05)

    model.add(Dense(num_y_signals,
                    activation='linear',
                    kernel_initializer=init))

# %% [markdown]
# ### Loss Function
#
# We will use Mean Squared Error (MSE) as the loss-function that will be minimized. This measures how closely the model's output matches the true output signals.
#
# However, at the beginning of a sequence, the model has only seen input-signals for a few time-steps, so its generated output may be very inaccurate. Using the loss-value for the early time-steps may cause the model to distort its later output. We therefore give the model a "warmup-period" of 5 time-steps where we don't use its accuracy in the loss-function, in hope of improving the accuracy for later time-steps.

# %%
warmup_steps = 5

# %%
def loss_mse_warmup(y_true, y_pred):
    """
    Calculate the Mean Squared Error between y_true and y_pred,
    but ignore the beginning "warmup" part of the sequences.
    
    y_true is the desired output.
    y_pred is the model's output.
    """

    # The shape of both input tensors are:
    # [batch_size, sequence_length, num_y_signals].

    # Ignore the "warmup" parts of the sequences
    # by taking slices of the tensors.
    y_true_slice = y_true[:, warmup_steps:, :]
    y_pred_slice = y_pred[:, warmup_steps:, :]

    # These sliced tensors both have this shape:
    # [batch_size, sequence_length - warmup_steps, num_y_signals]

    # Calculat the Mean Squared Error and use it as loss.
    mse = mean(square(y_true_slice - y_pred_slice))
    
    return mse

# %% [markdown]
# ### Compile Model
#
# This is the optimizer and the beginning learning-rate that we will use.

# %%
optimizer = Adam(lr=1e-3)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# We then compile the Keras model so it is ready for training.

# %%
model.compile(loss=loss_mse_warmup, optimizer=optimizer)

# %% [markdown]
# This is a very small model with only two layers. The output shape of `(None, None, 1)` means that the model will output a batch with an arbitrary number of sequences, each of which has an arbitrary number of observations, and each observation has 1 signals. This corresponds to the target signal we want to predict.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, None, 128)         4096
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 64)          8256
# _________________________________________________________________
# dense_2 (Dense)              (None, None, 32)          2080
# _________________________________________________________________
# dense_3 (Dense)              (None, None, 1)           33
# =================================================================
# Total params: 14,465
# Trainable params: 14,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Callback Functions
#
# During training we want to save checkpoints and log the progress to TensorBoard so we create the appropriate callbacks for Keras.
#
# This is the callback for writing checkpoints during training.

# %%
path_checkpoint = 'Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %% [markdown]
# This is the callback for stopping the optimization when performance worsens on the validation-set.

# %%
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=15, verbose=1)

# %% [markdown]
# This is the callback for writing the TensorBoard log during training.

# %%
callback_tensorboard = TensorBoard(log_dir='./base_logs/',
                                   histogram_freq=0,
                                   write_graph=False)

# %% [markdown]
# This callback reduces the learning-rate for the optimizer if the validation-loss has not improved since the last epoch (as indicated by `patience=0`). The learning-rate will be reduced by multiplying it with the given factor. We set a start learning-rate of 1e-3 above, so multiplying it by 0.1 gives a learning-rate of 1e-4. We don't want the learning-rate to go any lower than this.

# %%
callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.01,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

# %%
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr]

# %% [markdown]
# ## Train the Recurrent Neural Network
#
# We can now train the neural network.
#
# Note that a single "epoch" does not correspond to a single processing of the training-set, because of how the batch-generator randomly selects sub-sequences from the training-set. Instead we have selected `steps_per_epoch` so that one "epoch" is processed in a few minutes.
#
#
# Also note that the loss sometimes becomes `NaN` (not-a-number). This is often resolved by restarting and running the Notebook again. But it may also be caused by your neural network architecture, learning-rate, batch-size, sequence-length, etc. in which case you may have to modify those settings.

# %%
# %%time
model.fit(x=generator,
          epochs=500,
          steps_per_epoch=30,
          validation_data=validation_data,
          callbacks=callbacks)
# Out:
# Epoch 1/500
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0576 - val_loss: 0.0113
#
# Epoch 00001: val_loss improved from inf to 0.01130, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 2/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0105 - val_loss: 0.0094
#
# Epoch 00002: val_loss improved from 0.01130 to 0.00936, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 3/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0080 - val_loss: 0.0084
#
# Epoch 00003: val_loss improved from 0.00936 to 0.00842, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 4/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0070 - val_loss: 0.0079
#
# Epoch 00004: val_loss improved from 0.00842 to 0.00794, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 5/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0071 - val_loss: 0.0078
#
# Epoch 00005: val_loss improved from 0.00794 to 0.00776, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 6/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0060 - val_loss: 0.0075
#
# Epoch 00006: val_loss improved from 0.00776 to 0.00750, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 7/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0077 - val_loss: 0.0081
#
# Epoch 00007: val_loss did not improve from 0.00750
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/500
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0064 - val_loss: 0.0073
#
# Epoch 00008: val_loss improved from 0.00750 to 0.00726, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 9/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0063 - val_loss: 0.0073
#
# Epoch 00009: val_loss improved from 0.00726 to 0.00725, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 10/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0069 - val_loss: 0.0072
#
# Epoch 00010: val_loss improved from 0.00725 to 0.00720, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 11/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0072 - val_loss: 0.0072
#
# Epoch 00011: val_loss did not improve from 0.00720
# Epoch 12/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0065 - val_loss: 0.0071
#
# Epoch 00012: val_loss improved from 0.00720 to 0.00715, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 13/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0061 - val_loss: 0.0072
#
# Epoch 00013: val_loss did not improve from 0.00715
# Epoch 14/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0060 - val_loss: 0.0071
#
# Epoch 00014: val_loss improved from 0.00715 to 0.00715, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 15/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0071
#
# Epoch 00015: val_loss improved from 0.00715 to 0.00713, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 16/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0059 - val_loss: 0.0072
#
# Epoch 00016: val_loss did not improve from 0.00713
# Epoch 17/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0062 - val_loss: 0.0071
#
# Epoch 00017: val_loss improved from 0.00713 to 0.00713, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 18/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0072
#
# Epoch 00018: val_loss did not improve from 0.00713
# Epoch 19/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0070
#
# Epoch 00019: val_loss improved from 0.00713 to 0.00705, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 20/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0067 - val_loss: 0.0071
#
# Epoch 00020: val_loss did not improve from 0.00705
# Epoch 21/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0064 - val_loss: 0.0070
#
# Epoch 00021: val_loss improved from 0.00705 to 0.00704, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 22/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0066 - val_loss: 0.0070
#
# Epoch 00022: val_loss improved from 0.00704 to 0.00702, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 23/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0070
#
# Epoch 00023: val_loss improved from 0.00702 to 0.00699, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 24/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0064 - val_loss: 0.0071
#
# Epoch 00024: val_loss did not improve from 0.00699
# Epoch 25/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0062 - val_loss: 0.0071
#
# Epoch 00025: val_loss did not improve from 0.00699
# Epoch 26/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0060 - val_loss: 0.0069
#
# Epoch 00026: val_loss improved from 0.00699 to 0.00695, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 27/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0065 - val_loss: 0.0070
#
# Epoch 00027: val_loss did not improve from 0.00695
# Epoch 28/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0068 - val_loss: 0.0069
#
# Epoch 00028: val_loss improved from 0.00695 to 0.00686, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 29/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0066 - val_loss: 0.0069
#
# Epoch 00029: val_loss did not improve from 0.00686
# Epoch 30/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0064 - val_loss: 0.0070
#
# Epoch 00030: val_loss did not improve from 0.00686
# Epoch 31/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0056 - val_loss: 0.0068
#
# Epoch 00031: val_loss improved from 0.00686 to 0.00681, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 32/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0065 - val_loss: 0.0068
#
# Epoch 00032: val_loss did not improve from 0.00681
# Epoch 33/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0056 - val_loss: 0.0068
#
# Epoch 00033: val_loss did not improve from 0.00681
# Epoch 34/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0068
#
# Epoch 00034: val_loss improved from 0.00681 to 0.00680, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 35/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0068 - val_loss: 0.0067
#
# Epoch 00035: val_loss improved from 0.00680 to 0.00674, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 36/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0067
#
# Epoch 00036: val_loss improved from 0.00674 to 0.00673, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 37/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0059 - val_loss: 0.0067
#
# Epoch 00037: val_loss did not improve from 0.00673
# Epoch 38/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0062 - val_loss: 0.0067
#
# Epoch 00038: val_loss improved from 0.00673 to 0.00671, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 39/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0057 - val_loss: 0.0067
#
# Epoch 00039: val_loss improved from 0.00671 to 0.00670, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 40/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0063 - val_loss: 0.0067
#
# Epoch 00040: val_loss did not improve from 0.00670
# Epoch 41/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0066 - val_loss: 0.0067
#
# Epoch 00041: val_loss improved from 0.00670 to 0.00665, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 42/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0068 - val_loss: 0.0067
#
# Epoch 00042: val_loss did not improve from 0.00665
# Epoch 43/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0067
#
# Epoch 00043: val_loss did not improve from 0.00665
# Epoch 44/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0063 - val_loss: 0.0066
#
# Epoch 00044: val_loss improved from 0.00665 to 0.00659, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 45/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0063 - val_loss: 0.0067
#
# Epoch 00045: val_loss did not improve from 0.00659
# Epoch 46/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0059 - val_loss: 0.0067
#
# Epoch 00046: val_loss did not improve from 0.00659
# Epoch 47/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0068 - val_loss: 0.0066
#
# Epoch 00047: val_loss did not improve from 0.00659
# Epoch 48/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0060 - val_loss: 0.0066
#
# Epoch 00048: val_loss improved from 0.00659 to 0.00658, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 49/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0065
#
# Epoch 00049: val_loss improved from 0.00658 to 0.00652, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 50/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0065 - val_loss: 0.0066
#
# Epoch 00050: val_loss did not improve from 0.00652
# Epoch 51/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0065
#
# Epoch 00051: val_loss improved from 0.00652 to 0.00651, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 52/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0061 - val_loss: 0.0065
#
# Epoch 00052: val_loss improved from 0.00651 to 0.00648, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 53/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0056 - val_loss: 0.0065
#
# Epoch 00053: val_loss improved from 0.00648 to 0.00647, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 54/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0057 - val_loss: 0.0065
#
# Epoch 00054: val_loss did not improve from 0.00647
# Epoch 55/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0058 - val_loss: 0.0065
#
# Epoch 00055: val_loss did not improve from 0.00647
# Epoch 56/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0064 - val_loss: 0.0065
#
# Epoch 00056: val_loss did not improve from 0.00647
# Epoch 57/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0060 - val_loss: 0.0065
#
# Epoch 00057: val_loss did not improve from 0.00647
# Epoch 58/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00058: val_loss improved from 0.00647 to 0.00643, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 59/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0064
#
# Epoch 00059: val_loss improved from 0.00643 to 0.00641, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 60/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0072 - val_loss: 0.0065
#
# Epoch 00060: val_loss did not improve from 0.00641
# Epoch 61/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0064
#
# Epoch 00061: val_loss improved from 0.00641 to 0.00639, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 62/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00062: val_loss improved from 0.00639 to 0.00638, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 63/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0051 - val_loss: 0.0064
#
# Epoch 00063: val_loss did not improve from 0.00638
# Epoch 64/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0060 - val_loss: 0.0063
#
# Epoch 00064: val_loss improved from 0.00638 to 0.00635, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 65/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0048 - val_loss: 0.0064
#
# Epoch 00065: val_loss did not improve from 0.00635
# Epoch 66/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00066: val_loss did not improve from 0.00635
# Epoch 67/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0059 - val_loss: 0.0064
#
# Epoch 00067: val_loss did not improve from 0.00635
# Epoch 68/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0055 - val_loss: 0.0063
#
# Epoch 00068: val_loss improved from 0.00635 to 0.00632, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 69/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0064
#
# Epoch 00069: val_loss did not improve from 0.00632
# Epoch 70/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0063
#
# Epoch 00070: val_loss improved from 0.00632 to 0.00630, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 71/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0057 - val_loss: 0.0063
#
# Epoch 00071: val_loss improved from 0.00630 to 0.00628, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 72/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0062
#
# Epoch 00072: val_loss improved from 0.00628 to 0.00625, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 73/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0064
#
# Epoch 00073: val_loss did not improve from 0.00625
# Epoch 74/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0056 - val_loss: 0.0063
#
# Epoch 00074: val_loss did not improve from 0.00625
# Epoch 75/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0056 - val_loss: 0.0063
#
# Epoch 00075: val_loss did not improve from 0.00625
# Epoch 76/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0062
#
# Epoch 00076: val_loss improved from 0.00625 to 0.00622, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 77/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0063 - val_loss: 0.0062
#
# Epoch 00077: val_loss improved from 0.00622 to 0.00622, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 78/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0056 - val_loss: 0.0064
#
# Epoch 00078: val_loss did not improve from 0.00622
# Epoch 79/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0063 - val_loss: 0.0064
#
# Epoch 00079: val_loss did not improve from 0.00622
# Epoch 80/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00080: val_loss did not improve from 0.00622
# Epoch 81/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0067 - val_loss: 0.0062
#
# Epoch 00081: val_loss improved from 0.00622 to 0.00619, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 82/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0068 - val_loss: 0.0066
#
# Epoch 00082: val_loss did not improve from 0.00619
# Epoch 83/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0059 - val_loss: 0.0061
#
# Epoch 00083: val_loss improved from 0.00619 to 0.00614, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 84/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0060 - val_loss: 0.0061
#
# Epoch 00084: val_loss did not improve from 0.00614
# Epoch 85/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0062
#
# Epoch 00085: val_loss did not improve from 0.00614
# Epoch 86/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0061
#
# Epoch 00086: val_loss improved from 0.00614 to 0.00612, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 87/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0057 - val_loss: 0.0061
#
# Epoch 00087: val_loss improved from 0.00612 to 0.00611, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 88/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0061
#
# Epoch 00088: val_loss improved from 0.00611 to 0.00610, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 89/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0065
#
# Epoch 00089: val_loss did not improve from 0.00610
# Epoch 90/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0061
#
# Epoch 00090: val_loss improved from 0.00610 to 0.00608, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 91/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0049 - val_loss: 0.0062
#
# Epoch 00091: val_loss did not improve from 0.00608
# Epoch 92/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0061
#
# Epoch 00092: val_loss did not improve from 0.00608
# Epoch 93/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0062 - val_loss: 0.0060
#
# Epoch 00093: val_loss improved from 0.00608 to 0.00605, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 94/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0060
#
# Epoch 00094: val_loss improved from 0.00605 to 0.00603, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 95/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0061
#
# Epoch 00095: val_loss did not improve from 0.00603
# Epoch 96/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0061
#
# Epoch 00096: val_loss did not improve from 0.00603
# Epoch 97/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0053 - val_loss: 0.0061
#
# Epoch 00097: val_loss did not improve from 0.00603
# Epoch 98/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0060
#
# Epoch 00098: val_loss improved from 0.00603 to 0.00602, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 99/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0060
#
# Epoch 00099: val_loss improved from 0.00602 to 0.00602, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 100/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0061
#
# Epoch 00100: val_loss did not improve from 0.00602
# Epoch 101/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0060
#
# Epoch 00101: val_loss improved from 0.00602 to 0.00597, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 102/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0057 - val_loss: 0.0060
#
# Epoch 00102: val_loss did not improve from 0.00597
# Epoch 103/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0048 - val_loss: 0.0060
#
# Epoch 00103: val_loss did not improve from 0.00597
# Epoch 104/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0057 - val_loss: 0.0059
#
# Epoch 00104: val_loss improved from 0.00597 to 0.00595, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 105/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0059
#
# Epoch 00105: val_loss improved from 0.00595 to 0.00594, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 106/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0059
#
# Epoch 00106: val_loss improved from 0.00594 to 0.00593, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 107/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0057 - val_loss: 0.0059
#
# Epoch 00107: val_loss did not improve from 0.00593
# Epoch 108/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0060
#
# Epoch 00108: val_loss did not improve from 0.00593
# Epoch 109/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0060
#
# Epoch 00109: val_loss did not improve from 0.00593
# Epoch 110/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0059
#
# Epoch 00110: val_loss improved from 0.00593 to 0.00591, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 111/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0058 - val_loss: 0.0059
#
# Epoch 00111: val_loss improved from 0.00591 to 0.00591, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 112/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0059
#
# Epoch 00112: val_loss improved from 0.00591 to 0.00590, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 113/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0059
#
# Epoch 00113: val_loss did not improve from 0.00590
# Epoch 114/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0056 - val_loss: 0.0059
#
# Epoch 00114: val_loss did not improve from 0.00590
# Epoch 115/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0059
#
# Epoch 00115: val_loss improved from 0.00590 to 0.00588, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 116/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0053 - val_loss: 0.0059
#
# Epoch 00116: val_loss improved from 0.00588 to 0.00587, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 117/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0059
#
# Epoch 00117: val_loss improved from 0.00587 to 0.00586, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 118/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0059
#
# Epoch 00118: val_loss did not improve from 0.00586
# Epoch 119/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0056 - val_loss: 0.0060
#
# Epoch 00119: val_loss did not improve from 0.00586
# Epoch 120/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0049 - val_loss: 0.0059
#
# Epoch 00120: val_loss improved from 0.00586 to 0.00585, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 121/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0057 - val_loss: 0.0059
#
# Epoch 00121: val_loss improved from 0.00585 to 0.00585, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 122/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0058
#
# Epoch 00122: val_loss improved from 0.00585 to 0.00583, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 123/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0058
#
# Epoch 00123: val_loss improved from 0.00583 to 0.00581, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 124/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0059
#
# Epoch 00124: val_loss did not improve from 0.00581
# Epoch 125/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0059
#
# Epoch 00125: val_loss did not improve from 0.00581
# Epoch 126/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0058
#
# Epoch 00126: val_loss improved from 0.00581 to 0.00579, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 127/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0058
#
# Epoch 00127: val_loss improved from 0.00579 to 0.00578, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 128/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00128: val_loss did not improve from 0.00578
# Epoch 129/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0059
#
# Epoch 00129: val_loss did not improve from 0.00578
# Epoch 130/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0048 - val_loss: 0.0058
#
# Epoch 00130: val_loss improved from 0.00578 to 0.00577, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 131/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0058
#
# Epoch 00131: val_loss did not improve from 0.00577
# Epoch 132/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0049 - val_loss: 0.0058
#
# Epoch 00132: val_loss did not improve from 0.00577
# Epoch 133/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0044 - val_loss: 0.0059
#
# Epoch 00133: val_loss did not improve from 0.00577
# Epoch 134/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0059
#
# Epoch 00134: val_loss did not improve from 0.00577
# Epoch 135/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0057
#
# Epoch 00135: val_loss improved from 0.00577 to 0.00574, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 136/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0057
#
# Epoch 00136: val_loss improved from 0.00574 to 0.00571, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 137/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00137: val_loss did not improve from 0.00571
# Epoch 138/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0057
#
# Epoch 00138: val_loss did not improve from 0.00571
# Epoch 139/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0046 - val_loss: 0.0057
#
# Epoch 00139: val_loss improved from 0.00571 to 0.00571, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 140/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0057
#
# Epoch 00140: val_loss improved from 0.00571 to 0.00569, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 141/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0057
#
# Epoch 00141: val_loss did not improve from 0.00569
# Epoch 142/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0057
#
# Epoch 00142: val_loss improved from 0.00569 to 0.00568, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 143/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0057
#
# Epoch 00143: val_loss did not improve from 0.00568
# Epoch 144/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0057
#
# Epoch 00144: val_loss did not improve from 0.00568
# Epoch 145/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0057
#
# Epoch 00145: val_loss did not improve from 0.00568
# Epoch 146/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0058
#
# Epoch 00146: val_loss did not improve from 0.00568
# Epoch 147/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0048 - val_loss: 0.0056
#
# Epoch 00147: val_loss improved from 0.00568 to 0.00564, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 148/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0046 - val_loss: 0.0057
#
# Epoch 00148: val_loss did not improve from 0.00564
# Epoch 149/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0057
#
# Epoch 00149: val_loss did not improve from 0.00564
# Epoch 150/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0056
#
# Epoch 00150: val_loss improved from 0.00564 to 0.00562, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 151/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0056
#
# Epoch 00151: val_loss did not improve from 0.00562
# Epoch 152/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0048 - val_loss: 0.0056
#
# Epoch 00152: val_loss did not improve from 0.00562
# Epoch 153/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0057 - val_loss: 0.0057
#
# Epoch 00153: val_loss did not improve from 0.00562
# Epoch 154/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0057
#
# Epoch 00154: val_loss did not improve from 0.00562
# Epoch 155/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0057
#
# Epoch 00155: val_loss did not improve from 0.00562
# Epoch 156/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0055 - val_loss: 0.0056
#
# Epoch 00156: val_loss improved from 0.00562 to 0.00561, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 157/500
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0054 - val_loss: 0.0056
#
# Epoch 00157: val_loss improved from 0.00561 to 0.00561, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 158/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0056 - val_loss: 0.0056
#
# Epoch 00158: val_loss improved from 0.00561 to 0.00558, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 159/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0044 - val_loss: 0.0056
#
# Epoch 00159: val_loss did not improve from 0.00558
# Epoch 160/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0056
#
# Epoch 00160: val_loss did not improve from 0.00558
# Epoch 161/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0056
#
# Epoch 00161: val_loss did not improve from 0.00558
# Epoch 162/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0056
#
# Epoch 00162: val_loss did not improve from 0.00558
# Epoch 163/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0058 - val_loss: 0.0057
#
# Epoch 00163: val_loss did not improve from 0.00558
# Epoch 164/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0056
#
# Epoch 00164: val_loss improved from 0.00558 to 0.00557, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 165/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0056
#
# Epoch 00165: val_loss did not improve from 0.00557
# Epoch 166/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0050 - val_loss: 0.0056
#
# Epoch 00166: val_loss did not improve from 0.00557
# Epoch 167/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0056
#
# Epoch 00167: val_loss did not improve from 0.00557
# Epoch 168/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0048 - val_loss: 0.0056
#
# Epoch 00168: val_loss did not improve from 0.00557
# Epoch 169/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0053 - val_loss: 0.0057
#
# Epoch 00169: val_loss did not improve from 0.00557
# Epoch 170/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0056
#
# Epoch 00170: val_loss did not improve from 0.00557
# Epoch 171/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0039 - val_loss: 0.0058
#
# Epoch 00171: val_loss did not improve from 0.00557
# Epoch 172/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0050 - val_loss: 0.0056
#
# Epoch 00172: val_loss improved from 0.00557 to 0.00555, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 173/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0056
#
# Epoch 00173: val_loss did not improve from 0.00555
# Epoch 174/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0055
#
# Epoch 00174: val_loss improved from 0.00555 to 0.00549, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 175/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0055
#
# Epoch 00175: val_loss did not improve from 0.00549
# Epoch 176/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0055 - val_loss: 0.0055
#
# Epoch 00176: val_loss did not improve from 0.00549
# Epoch 177/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0056
#
# Epoch 00177: val_loss did not improve from 0.00549
# Epoch 178/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0056
#
# Epoch 00178: val_loss did not improve from 0.00549
# Epoch 179/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0056
#
# Epoch 00179: val_loss did not improve from 0.00549
# Epoch 180/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0044 - val_loss: 0.0056
#
# Epoch 00180: val_loss did not improve from 0.00549
# Epoch 181/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0055
#
# Epoch 00181: val_loss improved from 0.00549 to 0.00547, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 182/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0048 - val_loss: 0.0056
#
# Epoch 00182: val_loss did not improve from 0.00547
# Epoch 183/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0055
#
# Epoch 00183: val_loss did not improve from 0.00547
# Epoch 184/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0055
#
# Epoch 00184: val_loss did not improve from 0.00547
# Epoch 185/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00185: val_loss improved from 0.00547 to 0.00544, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 186/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0055
#
# Epoch 00186: val_loss did not improve from 0.00544
# Epoch 187/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0054
#
# Epoch 00187: val_loss improved from 0.00544 to 0.00543, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 188/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0050 - val_loss: 0.0054
#
# Epoch 00188: val_loss improved from 0.00543 to 0.00541, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 189/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0055
#
# Epoch 00189: val_loss did not improve from 0.00541
# Epoch 190/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0044 - val_loss: 0.0055
#
# Epoch 00190: val_loss did not improve from 0.00541
# Epoch 191/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0054 - val_loss: 0.0056
#
# Epoch 00191: val_loss did not improve from 0.00541
# Epoch 192/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0046 - val_loss: 0.0054
#
# Epoch 00192: val_loss did not improve from 0.00541
# Epoch 193/500
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00193: val_loss improved from 0.00541 to 0.00540, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 194/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0044 - val_loss: 0.0054
#
# Epoch 00194: val_loss did not improve from 0.00540
# Epoch 195/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0045 - val_loss: 0.0054
#
# Epoch 00195: val_loss improved from 0.00540 to 0.00539, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 196/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0049 - val_loss: 0.0054
#
# Epoch 00196: val_loss improved from 0.00539 to 0.00538, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 197/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00197: val_loss improved from 0.00538 to 0.00537, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 198/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0048 - val_loss: 0.0054
#
# Epoch 00198: val_loss did not improve from 0.00537
# Epoch 199/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0043 - val_loss: 0.0054
#
# Epoch 00199: val_loss did not improve from 0.00537
# Epoch 200/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0054
#
# Epoch 00200: val_loss did not improve from 0.00537
# Epoch 201/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0042 - val_loss: 0.0054
#
# Epoch 00201: val_loss did not improve from 0.00537
# Epoch 202/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0041 - val_loss: 0.0054
#
# Epoch 00202: val_loss did not improve from 0.00537
# Epoch 203/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0050 - val_loss: 0.0054
#
# Epoch 00203: val_loss improved from 0.00537 to 0.00536, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 204/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00204: val_loss did not improve from 0.00536
# Epoch 205/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00205: val_loss improved from 0.00536 to 0.00532, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 206/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0044 - val_loss: 0.0053
#
# Epoch 00206: val_loss did not improve from 0.00532
# Epoch 207/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0046 - val_loss: 0.0055
#
# Epoch 00207: val_loss did not improve from 0.00532
# Epoch 208/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0039 - val_loss: 0.0053
#
# Epoch 00208: val_loss did not improve from 0.00532
# Epoch 209/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0042 - val_loss: 0.0054
#
# Epoch 00209: val_loss did not improve from 0.00532
# Epoch 210/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0042 - val_loss: 0.0053
#
# Epoch 00210: val_loss improved from 0.00532 to 0.00530, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 211/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0053 - val_loss: 0.0053
#
# Epoch 00211: val_loss did not improve from 0.00530
# Epoch 212/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00212: val_loss did not improve from 0.00530
# Epoch 213/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00213: val_loss did not improve from 0.00530
# Epoch 214/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0055
#
# Epoch 00214: val_loss did not improve from 0.00530
# Epoch 215/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0051 - val_loss: 0.0054
#
# Epoch 00215: val_loss did not improve from 0.00530
# Epoch 216/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0041 - val_loss: 0.0053
#
# Epoch 00216: val_loss did not improve from 0.00530
# Epoch 217/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0050 - val_loss: 0.0053
#
# Epoch 00217: val_loss improved from 0.00530 to 0.00527, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 218/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0046 - val_loss: 0.0053
#
# Epoch 00218: val_loss did not improve from 0.00527
# Epoch 219/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0053
#
# Epoch 00219: val_loss did not improve from 0.00527
# Epoch 220/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0053
#
# Epoch 00220: val_loss did not improve from 0.00527
# Epoch 221/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0044 - val_loss: 0.0053
#
# Epoch 00221: val_loss did not improve from 0.00527
# Epoch 222/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0053
#
# Epoch 00222: val_loss improved from 0.00527 to 0.00526, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 223/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0041 - val_loss: 0.0053
#
# Epoch 00223: val_loss did not improve from 0.00526
# Epoch 224/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0052 - val_loss: 0.0053
#
# Epoch 00224: val_loss did not improve from 0.00526
# Epoch 225/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0037 - val_loss: 0.0053
#
# Epoch 00225: val_loss did not improve from 0.00526
# Epoch 226/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0044 - val_loss: 0.0052
#
# Epoch 00226: val_loss improved from 0.00526 to 0.00524, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 227/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0053 - val_loss: 0.0054
#
# Epoch 00227: val_loss did not improve from 0.00524
# Epoch 228/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00228: val_loss did not improve from 0.00524
# Epoch 229/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00229: val_loss did not improve from 0.00524
# Epoch 230/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00230: val_loss did not improve from 0.00524
# Epoch 231/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0048 - val_loss: 0.0052
#
# Epoch 00231: val_loss did not improve from 0.00524
# Epoch 232/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0053
#
# Epoch 00232: val_loss did not improve from 0.00524
# Epoch 233/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00233: val_loss did not improve from 0.00524
# Epoch 234/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0047 - val_loss: 0.0053
#
# Epoch 00234: val_loss did not improve from 0.00524
# Epoch 235/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0041 - val_loss: 0.0053
#
# Epoch 00235: val_loss did not improve from 0.00524
# Epoch 236/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0052
#
# Epoch 00236: val_loss did not improve from 0.00524
# Epoch 237/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0052
#
# Epoch 00237: val_loss improved from 0.00524 to 0.00521, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 238/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0056 - val_loss: 0.0052
#
# Epoch 00238: val_loss improved from 0.00521 to 0.00519, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 239/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0054
#
# Epoch 00239: val_loss did not improve from 0.00519
# Epoch 240/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0052
#
# Epoch 00240: val_loss improved from 0.00519 to 0.00519, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 241/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0042 - val_loss: 0.0052
#
# Epoch 00241: val_loss improved from 0.00519 to 0.00519, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 242/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0043 - val_loss: 0.0052
#
# Epoch 00242: val_loss did not improve from 0.00519
# Epoch 243/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0053 - val_loss: 0.0053
#
# Epoch 00243: val_loss did not improve from 0.00519
# Epoch 244/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0052
#
# Epoch 00244: val_loss did not improve from 0.00519
# Epoch 245/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0049 - val_loss: 0.0055
#
# Epoch 00245: val_loss did not improve from 0.00519
# Epoch 246/500
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0054 - val_loss: 0.0054
#
# Epoch 00246: val_loss did not improve from 0.00519
# Epoch 247/500
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0048 - val_loss: 0.0052
#
# Epoch 00247: val_loss improved from 0.00519 to 0.00517, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 248/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0039 - val_loss: 0.0052
#
# Epoch 00248: val_loss improved from 0.00517 to 0.00517, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 249/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0046 - val_loss: 0.0052
#
# Epoch 00249: val_loss did not improve from 0.00517
# Epoch 250/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0046 - val_loss: 0.0052
#
# Epoch 00250: val_loss did not improve from 0.00517
# Epoch 251/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0052
#
# Epoch 00251: val_loss did not improve from 0.00517
# Epoch 252/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0052
#
# Epoch 00252: val_loss did not improve from 0.00517
# Epoch 253/500
# ...
#
# Epoch 00379: val_loss did not improve from 0.00474
# Epoch 380/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0041 - val_loss: 0.0048
#
# Epoch 00380: val_loss did not improve from 0.00474
# Epoch 381/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0048
#
# Epoch 00381: val_loss did not improve from 0.00474
# Epoch 382/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00382: val_loss improved from 0.00474 to 0.00471, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 383/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0045 - val_loss: 0.0048
#
# Epoch 00383: val_loss did not improve from 0.00471
# Epoch 384/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00384: val_loss improved from 0.00471 to 0.00471, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 385/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0050 - val_loss: 0.0047
#
# Epoch 00385: val_loss did not improve from 0.00471
# Epoch 386/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0043 - val_loss: 0.0048
#
# Epoch 00386: val_loss did not improve from 0.00471
# Epoch 387/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0039 - val_loss: 0.0047
#
# Epoch 00387: val_loss did not improve from 0.00471
# Epoch 388/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00388: val_loss did not improve from 0.00471
# Epoch 389/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0035 - val_loss: 0.0047
#
# Epoch 00389: val_loss did not improve from 0.00471
# Epoch 390/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0048
#
# Epoch 00390: val_loss did not improve from 0.00471
# Epoch 391/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0038 - val_loss: 0.0047
#
# Epoch 00391: val_loss did not improve from 0.00471
# Epoch 392/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0048
#
# Epoch 00392: val_loss did not improve from 0.00471
# Epoch 393/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0044 - val_loss: 0.0050
#
# Epoch 00393: val_loss did not improve from 0.00471
# Epoch 394/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0044 - val_loss: 0.0048
#
# Epoch 00394: val_loss did not improve from 0.00471
# Epoch 395/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0041 - val_loss: 0.0047
#
# Epoch 00395: val_loss did not improve from 0.00471
# Epoch 396/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00396: val_loss improved from 0.00471 to 0.00469, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 397/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0034 - val_loss: 0.0047
#
# Epoch 00397: val_loss improved from 0.00469 to 0.00468, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 398/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0041 - val_loss: 0.0048
#
# Epoch 00398: val_loss did not improve from 0.00468
# Epoch 399/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0040 - val_loss: 0.0048
#
# Epoch 00399: val_loss did not improve from 0.00468
# Epoch 400/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0036 - val_loss: 0.0047
#
# Epoch 00400: val_loss did not improve from 0.00468
# Epoch 401/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0043 - val_loss: 0.0048
#
# Epoch 00401: val_loss did not improve from 0.00468
# Epoch 402/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0043 - val_loss: 0.0047
#
# Epoch 00402: val_loss did not improve from 0.00468
# Epoch 403/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0036 - val_loss: 0.0047
#
# Epoch 00403: val_loss did not improve from 0.00468
# Epoch 404/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0039 - val_loss: 0.0047
#
# Epoch 00404: val_loss did not improve from 0.00468
# Epoch 405/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00405: val_loss did not improve from 0.00468
# Epoch 406/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0046 - val_loss: 0.0047
#
# Epoch 00406: val_loss did not improve from 0.00468
# Epoch 407/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0044 - val_loss: 0.0048
#
# Epoch 00407: val_loss did not improve from 0.00468
# Epoch 408/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0040 - val_loss: 0.0047
#
# Epoch 00408: val_loss did not improve from 0.00468
# Epoch 409/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00409: val_loss improved from 0.00468 to 0.00464, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 410/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0036 - val_loss: 0.0047
#
# Epoch 00410: val_loss did not improve from 0.00464
# Epoch 411/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0043 - val_loss: 0.0047
#
# Epoch 00411: val_loss did not improve from 0.00464
# Epoch 412/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0037 - val_loss: 0.0047
#
# Epoch 00412: val_loss did not improve from 0.00464
# Epoch 413/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00413: val_loss did not improve from 0.00464
# Epoch 414/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0044 - val_loss: 0.0047
#
# Epoch 00414: val_loss did not improve from 0.00464
# Epoch 415/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0043 - val_loss: 0.0047
#
# Epoch 00415: val_loss did not improve from 0.00464
# Epoch 416/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0035 - val_loss: 0.0047
#
# Epoch 00416: val_loss did not improve from 0.00464
# Epoch 417/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00417: val_loss did not improve from 0.00464
# Epoch 418/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0049 - val_loss: 0.0048
#
# Epoch 00418: val_loss did not improve from 0.00464
# Epoch 419/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00419: val_loss improved from 0.00464 to 0.00461, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 420/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0039 - val_loss: 0.0047
#
# Epoch 00420: val_loss did not improve from 0.00461
# Epoch 421/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00421: val_loss did not improve from 0.00461
# Epoch 422/500
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00422: val_loss did not improve from 0.00461
# Epoch 423/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00423: val_loss did not improve from 0.00461
# Epoch 424/500
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00424: val_loss did not improve from 0.00461
# Epoch 425/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0048
#
# Epoch 00425: val_loss did not improve from 0.00461
# Epoch 426/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0034 - val_loss: 0.0046
#
# Epoch 00426: val_loss improved from 0.00461 to 0.00458, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 427/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0046 - val_loss: 0.0047
#
# Epoch 00427: val_loss did not improve from 0.00458
# Epoch 428/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00428: val_loss did not improve from 0.00458
# Epoch 429/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00429: val_loss did not improve from 0.00458
# Epoch 430/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00430: val_loss did not improve from 0.00458
# Epoch 431/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0041 - val_loss: 0.0046
#
# Epoch 00431: val_loss did not improve from 0.00458
# Epoch 432/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0049 - val_loss: 0.0047
#
# Epoch 00432: val_loss did not improve from 0.00458
# Epoch 433/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0044 - val_loss: 0.0046
#
# Epoch 00433: val_loss improved from 0.00458 to 0.00458, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 434/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0044 - val_loss: 0.0046
#
# Epoch 00434: val_loss did not improve from 0.00458
# Epoch 435/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00435: val_loss did not improve from 0.00458
# Epoch 436/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0035 - val_loss: 0.0046
#
# Epoch 00436: val_loss did not improve from 0.00458
# Epoch 437/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0046
#
# Epoch 00437: val_loss improved from 0.00458 to 0.00456, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 438/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0048
#
# Epoch 00438: val_loss did not improve from 0.00456
# Epoch 439/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0043 - val_loss: 0.0047
#
# Epoch 00439: val_loss did not improve from 0.00456
# Epoch 440/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0045
#
# Epoch 00440: val_loss improved from 0.00456 to 0.00455, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 441/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0039 - val_loss: 0.0047
#
# Epoch 00441: val_loss did not improve from 0.00455
# Epoch 442/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00442: val_loss improved from 0.00455 to 0.00453, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 443/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00443: val_loss did not improve from 0.00453
# Epoch 444/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0041 - val_loss: 0.0046
#
# Epoch 00444: val_loss did not improve from 0.00453
# Epoch 445/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0047
#
# Epoch 00445: val_loss did not improve from 0.00453
# Epoch 446/500
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0041 - val_loss: 0.0046
#
# Epoch 00446: val_loss did not improve from 0.00453
# Epoch 447/500
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00447: val_loss did not improve from 0.00453
# Epoch 448/500
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00448: val_loss did not improve from 0.00453
# Epoch 449/500
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0042 - val_loss: 0.0045
#
# Epoch 00449: val_loss improved from 0.00453 to 0.00450, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 450/500
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00450: val_loss did not improve from 0.00450
# Epoch 451/500
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0041 - val_loss: 0.0045
#
# Epoch 00451: val_loss did not improve from 0.00450
# Epoch 452/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0044 - val_loss: 0.0046
#
# Epoch 00452: val_loss did not improve from 0.00450
# Epoch 453/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0039 - val_loss: 0.0046
#
# Epoch 00453: val_loss did not improve from 0.00450
# Epoch 454/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0044 - val_loss: 0.0045
#
# Epoch 00454: val_loss did not improve from 0.00450
# Epoch 455/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0042 - val_loss: 0.0047
#
# Epoch 00455: val_loss did not improve from 0.00450
# Epoch 456/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00456: val_loss did not improve from 0.00450
# Epoch 457/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0034 - val_loss: 0.0046
#
# Epoch 00457: val_loss did not improve from 0.00450
# Epoch 458/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0037 - val_loss: 0.0047
#
# Epoch 00458: val_loss did not improve from 0.00450
# Epoch 459/500
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0046 - val_loss: 0.0045
#
# Epoch 00459: val_loss improved from 0.00450 to 0.00450, saving model to Training_checkpoints/base_finaltuning_checkpoint_splittrivial.keras
# Epoch 460/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0043 - val_loss: 0.0046
#
# Epoch 00460: val_loss did not improve from 0.00450
# Epoch 461/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00461: val_loss did not improve from 0.00450
# Epoch 462/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0046 - val_loss: 0.0047
#
# Epoch 00462: val_loss did not improve from 0.00450
# Epoch 463/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0041 - val_loss: 0.0045
#
# Epoch 00463: val_loss did not improve from 0.00450
# Epoch 464/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0043 - val_loss: 0.0046
#
# Epoch 00464: val_loss did not improve from 0.00450
# Epoch 465/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0039 - val_loss: 0.0045
#
# Epoch 00465: val_loss did not improve from 0.00450
# Epoch 466/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00466: val_loss did not improve from 0.00450
# Epoch 467/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00467: val_loss did not improve from 0.00450
# Epoch 468/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0038 - val_loss: 0.0046
#
# Epoch 00468: val_loss did not improve from 0.00450
# Epoch 469/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0037 - val_loss: 0.0046
#
# Epoch 00469: val_loss did not improve from 0.00450
# Epoch 470/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0038 - val_loss: 0.0046
#
# Epoch 00470: val_loss did not improve from 0.00450
# Epoch 471/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0041 - val_loss: 0.0045
#
# Epoch 00471: val_loss did not improve from 0.00450
# Epoch 472/500
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00472: val_loss did not improve from 0.00450
# Epoch 473/500
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00473: val_loss did not improve from 0.00450
# Epoch 474/500
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0038 - val_loss: 0.0045
#
# Epoch 00474: val_loss did not improve from 0.00450
# Epoch 00474: early stopping
# CPU times: user 11min 21s, sys: 22.7 s, total: 11min 44s
# Wall time: 7min 14s

# %% [markdown]
# ### Load Checkpoint
#
# Because we use early-stopping when training the model, it is possible that the model's performance has worsened on the test-set for several epochs before training was stopped. We therefore reload the last saved checkpoint, which should have the best performance on the test-set.

# %%
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %% [markdown]
# ## Performance on Test-Set
#
# We can now evaluate the model's performance on the test-set. This function expects a batch of data, but we will just use one long time-series for the test-set, so we just expand the array-dimensionality to create a batch with that one sequence.

# %%
result = model.evaluate(x=np.expand_dims(x_test_scaled, axis=0),
                        y=np.expand_dims(y_test_scaled, axis=0))
# Out:
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0065

# %%
print("loss (test-set):", result)
# Out:
# loss (test-set): 0.00650080107152462

# %%
# If you have several metrics you can use this instead.
if False:
    for res, metric in zip(result, model.metrics_names):
        print("{0}: {1:.3e}".format(metric, res))

# %% [markdown]
# ## Generate Predictions
#
# This helper-function plots the predicted and true output-signals.

# %%
def plot_comparison_fulltest():
    """
    Plot the predicted and true output-signals of test set
    """
    # Use test-data.
    x = x_test_scaled
    y_true = y_test
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    signal = 'EMISSIONS_2019'
    # Get the output-signal predicted by the model.
    signal_pred = y_pred_rescaled[:]
    
    # Get the true output-signal from the data-set.
    signal_true = y_true[:]

    # Make the plotting-canvas bigger.
    plt.figure(figsize=(15,5))
    
    # Plot and compare the two signals.
    plt.plot(signal_true, label='true')
    plt.plot(signal_pred, label='pred', alpha=0.80)
    
    # Plot grey box for warmup-period.
    p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)
    
    # Plot labels etc.
    plt.ylabel(signal)
    plt.legend()
    plt.show()

# %% [markdown]
# We can now plot an example of predicted output-signal. It is important to understand what these plots show, as they are actually a bit more complicated than you might think.

# %%
plot_comparison_fulltest()

# %% [markdown]
# ## Improvements

# %% [markdown]
# The model at least seems to perform a little better than the base model with just location, the overall performance is not sufficient yet since we train the model in the wrong way.
# Here there are the next improvements:
# - Train the model modifying the way the generator gives the data. Right now it select randomly a subsequence from the overall training set, so it is very likely that a single subsequence may contain the end of the final day for a location and the first day of the next location. So a way to improve is to force the generator to select a random subsequene from a single random location. Can be done quite easily by choosing randomly a single location (from the cartesian product of latitudes and longitudes) and than choose randomly a subsequence inside this selection.
# - Right now the test set contains latitudes and longitudes never seen in the training set, shuffling smartly the dataset may solve this but pay attention to the previous point
# - Tune Hyperparameters through CROSS-VALIDATION !!
# - Not use the Test set as Validation set !!
