# %% [markdown]
# #Create the environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/ESoWC
# Out:
# /content/drive/My Drive/ESoWC

# %%
import pandas as pd
import xarray as xr
import numpy as np

# %%
dataset = xr.open_dataset('MAY_HOURLY_2019_NOX_and_weather.nc')
dataset = dataset.sortby(['latitude','longitude','time'])  
dataframe = dataset.to_dataframe()
dataframe.head()
# Out:
#                                         EMISSIONS_2019  ...  tot_wind
# latitude longitude time                                 ...
# 43.0     4.0       2019-05-01 01:00:00    1.150046e-12  ...  5.914585
#                    2019-05-01 02:00:00    7.820315e-13  ...  5.532602
#                    2019-05-01 03:00:00    6.900278e-13  ...  5.150619
#                    2019-05-01 04:00:00    6.440259e-13  ...  4.818472
#                    2019-05-01 05:00:00    7.820315e-13  ...  4.486325
#
# [5 rows x 15 columns]

# %%
dataframe['tmp_shifted_9']=dataframe.tmp.shift(periods=9)
#dataframe=dataframe.dropna(subset = ['tmp_shifted_9'])
dataframe.head(15)
# Out:
#                                         EMISSIONS_2019  ...  tmp_shifted_9
# latitude longitude time                                 ...
# 43.0     4.0       2019-05-01 01:00:00    1.150046e-12  ...            NaN
#                    2019-05-01 02:00:00    7.820315e-13  ...            NaN
#                    2019-05-01 03:00:00    6.900278e-13  ...            NaN
#                    2019-05-01 04:00:00    6.440259e-13  ...            NaN
#                    2019-05-01 05:00:00    7.820315e-13  ...            NaN
#                    2019-05-01 06:00:00    1.380056e-12  ...            NaN
#                    2019-05-01 07:00:00    4.416177e-12  ...            NaN
#                    2019-05-01 08:00:00    8.050324e-12  ...            NaN
#                    2019-05-01 09:00:00    8.142327e-12  ...            NaN
#                    2019-05-01 10:00:00    6.716270e-12  ...     263.693481
#                    2019-05-01 11:00:00    5.842235e-12  ...     263.244812
#                    2019-05-01 12:00:00    5.474221e-12  ...     262.796143
#                    2019-05-01 13:00:00    5.750231e-12  ...     262.032562
#                    2019-05-01 14:00:00    6.118246e-12  ...     261.268951
#                    2019-05-01 15:00:00    6.072244e-12  ...     260.505371
#
# [15 rows x 16 columns]

# %%
dataframe['rel_hum_shifted_9']=dataframe.rel_hum.shift(periods=9)
#dataframe=dataframe.dropna(subset = ['tmp_shifted_9'])
dataframe.head(15)
# Out:
#                                         EMISSIONS_2019  ...  rel_hum_shifted_9
# latitude longitude time                                 ...
# 43.0     4.0       2019-05-01 01:00:00    1.150046e-12  ...                NaN
#                    2019-05-01 02:00:00    7.820315e-13  ...                NaN
#                    2019-05-01 03:00:00    6.900278e-13  ...                NaN
#                    2019-05-01 04:00:00    6.440259e-13  ...                NaN
#                    2019-05-01 05:00:00    7.820315e-13  ...                NaN
#                    2019-05-01 06:00:00    1.380056e-12  ...                NaN
#                    2019-05-01 07:00:00    4.416177e-12  ...                NaN
#                    2019-05-01 08:00:00    8.050324e-12  ...                NaN
#                    2019-05-01 09:00:00    8.142327e-12  ...                NaN
#                    2019-05-01 10:00:00    6.716270e-12  ...           0.000227
#                    2019-05-01 11:00:00    5.842235e-12  ...           0.000235
#                    2019-05-01 12:00:00    5.474221e-12  ...           0.000243
#                    2019-05-01 13:00:00    5.750231e-12  ...           0.000264
#                    2019-05-01 14:00:00    6.118246e-12  ...           0.000284
#                    2019-05-01 15:00:00    6.072244e-12  ...           0.000304
#
# [15 rows x 17 columns]

# %%
df_to_use=dataframe [['EMISSIONS_2019','tmp','tmp_shifted_9','rel_hum','rel_hum_shifted_9']]
df_to_use.head()
# Out:
#                                         EMISSIONS_2019  ...  rel_hum_shifted_9
# latitude longitude time                                 ...
# 43.0     4.0       2019-05-01 01:00:00    1.150046e-12  ...                NaN
#                    2019-05-01 02:00:00    7.820315e-13  ...                NaN
#                    2019-05-01 03:00:00    6.900278e-13  ...                NaN
#                    2019-05-01 04:00:00    6.440259e-13  ...                NaN
#                    2019-05-01 05:00:00    7.820315e-13  ...                NaN
#
# [5 rows x 5 columns]

# %%
ds_to_use=df_to_use.to_xarray()
ds_to_use
# Out:
# <xarray.Dataset>
# Dimensions:            (latitude: 33, longitude: 33, time: 720)
# Coordinates:
#   * latitude           (latitude) float64 43.0 43.25 43.5 ... 50.5 50.75 51.0
#   * longitude          (longitude) float64 4.0 4.25 4.5 4.75 ... 11.5 11.75 12.0
#   * time               (time) datetime64[ns] 2019-05-01T01:00:00 ... 2019-05-31
# Data variables:
#     EMISSIONS_2019     (latitude, longitude, time) float64 1.15e-12 ... 1.858...
#     tmp                (latitude, longitude, time) float64 263.7 263.2 ... 269.5
#     tmp_shifted_9      (latitude, longitude, time) float64 nan nan ... 273.8
#     rel_hum            (latitude, longitude, time) float64 0.0002269 ... 0.00...
#     rel_hum_shifted_9  (latitude, longitude, time) float64 nan nan ... 0.0001016

# %%
ds_to_use.to_netcdf('dataset_weather_for_model.nc', 'w', 'NETCDF4')
